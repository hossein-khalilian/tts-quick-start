# %%
import re
import os
import requests
from IPython.display import Audio, display

# %%
# GitHub API URL for the release by tag
url = "https://api.github.com/repos/k2-fsa/sherpa-onnx/releases/tags/tts-models"

# Send GET request
response = requests.get(url)

# Check if request was successful
tts_models = {}
if response.status_code == 200:
    data = response.json()
    assets = data.get('assets', [])
    
    print("Assets found:")
    for asset in assets:
        if re.search(r'-fa[-_]', asset["name"]):
            tts_models[asset["name"].split(".")[0]] = asset["browser_download_url"]
            print(f"- {asset['name']}")
            print(f"  Download URL: {asset['browser_download_url']}\n")
else:
    print(f"Failed to fetch release info: {response.status_code}")
# Out:
# Assets found:
# - vits-piper-fa-haaniye_low.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa-haaniye_low.tar.bz2
#
# - vits-mimic3-fa-haaniye_low.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-mimic3-fa-haaniye_low.tar.bz2
#
# - vits-piper-fa_en-rezahedayatfar-ibrahimwalk-medium.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_en-rezahedayatfar-ibrahimwalk-medium.tar.bz2
#
# - matcha-tts-fa_en-musa.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/matcha-tts-fa_en-musa.tar.bz2
#
# - matcha-tts-fa_en-khadijah.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/matcha-tts-fa_en-khadijah.tar.bz2
#
# - vits-piper-fa_IR-gyro-medium.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-gyro-medium.tar.bz2
#
# - vits-piper-fa_IR-gyro-medium-int8.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-gyro-medium-int8.tar.bz2
#
# - vits-piper-fa_IR-gyro-medium-fp16.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-gyro-medium-fp16.tar.bz2
#
# - vits-piper-fa_IR-ganji_adabi-medium.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-ganji_adabi-medium.tar.bz2
#
# - vits-piper-fa_IR-ganji_adabi-medium-int8.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-ganji_adabi-medium-int8.tar.bz2
#
# - vits-piper-fa_IR-ganji_adabi-medium-fp16.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-ganji_adabi-medium-fp16.tar.bz2
#
# - vits-piper-fa_IR-reza_ibrahim-medium.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-reza_ibrahim-medium.tar.bz2
#
# - vits-piper-fa_IR-reza_ibrahim-medium-int8.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-reza_ibrahim-medium-int8.tar.bz2
#
# - vits-piper-fa_IR-reza_ibrahim-medium-fp16.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-reza_ibrahim-medium-fp16.tar.bz2
#
# - vits-piper-fa_IR-ganji-medium.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-ganji-medium.tar.bz2
#
# - vits-piper-fa_IR-ganji-medium-int8.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-ganji-medium-int8.tar.bz2
#
# - vits-piper-fa_IR-ganji-medium-fp16.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-ganji-medium-fp16.tar.bz2
#
# - vits-piper-fa_IR-amir-medium.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-amir-medium.tar.bz2
#
# - vits-piper-fa_IR-amir-medium-int8.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-amir-medium-int8.tar.bz2
#
# - vits-piper-fa_IR-amir-medium-fp16.tar.bz2
#   Download URL: https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-fa_IR-amir-medium-fp16.tar.bz2

# %%
list(tts_models.keys())
# Out:
# ['vits-piper-fa-haaniye_low',
#  'vits-mimic3-fa-haaniye_low',
#  'vits-piper-fa_en-rezahedayatfar-ibrahimwalk-medium',
#  'matcha-tts-fa_en-musa',
#  'matcha-tts-fa_en-khadijah',
#  'vits-piper-fa_IR-gyro-medium',
#  'vits-piper-fa_IR-gyro-medium-int8',
#  'vits-piper-fa_IR-gyro-medium-fp16',
#  'vits-piper-fa_IR-ganji_adabi-medium',
#  'vits-piper-fa_IR-ganji_adabi-medium-int8',
#  'vits-piper-fa_IR-ganji_adabi-medium-fp16',
#  'vits-piper-fa_IR-reza_ibrahim-medium',
#  'vits-piper-fa_IR-reza_ibrahim-medium-int8',
#  'vits-piper-fa_IR-reza_ibrahim-medium-fp16',
#  'vits-piper-fa_IR-ganji-medium',
#  'vits-piper-fa_IR-ganji-medium-int8',
#  'vits-piper-fa_IR-ganji-medium-fp16',
#  'vits-piper-fa_IR-amir-medium',
#  'vits-piper-fa_IR-amir-medium-int8',
#  'vits-piper-fa_IR-amir-medium-fp16']

# %%
url = "http://host.docker.internal:5000/speech/generate-speech"
for tts_model in list(tts_models.keys()):
    payload = {
        "text": "سلام! صبح شما هم بخیر و پر از طراوت",
        "model": tts_model,
        # "speed": 1.0
    }
    headers = {"Content-Type": "application/json"}
    
    response = requests.post(url, json=payload, headers=headers)
    
    # Step 2: Check and parse response
    if response.status_code == 200:
        data = response.json()
        file_path = data.get("file_url").replace("dev", "jovyan")
    
        if file_path and os.path.exists(file_path):
            print(f"Playing audio: {file_path}")
            display(Audio(file_path))
        else:
            print("Audio file not found at path:", file_path)
    else:
        print("Request failed:", response.status_code, response.text)
# Out:
# Playing audio: /home/jovyan/.cache/generated_audios/vits-piper-fa-haaniye_low_e6537de6.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Request failed: 500 {
#   "error": "Invalid TTS configuration"
# }
#
# Playing audio: /home/jovyan/.cache/generated_audios/vits-piper-fa_en-rezahedayatfar-ibrahimwalk-medium_1e076ca0.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Request failed: 500 {
#   "error": "Invalid TTS configuration"
# }
#
# Request failed: 500 {
#   "error": "Invalid TTS configuration"
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 10
#       3 payload = {
#       4     "text": "سلام! صبح شما هم بخیر و پر از طراوت",
#       5     "model": tts_model,
#       6     # "speed": 1.0
#       7 }
#       8 headers = {"Content-Type": "application/json"}
# ---> 10 response = requests.post(url, json=payload, headers=headers)
#      12 # Step 2: Check and parse response
#      13 if response.status_code == 200:
#
# File /opt/conda/lib/python3.12/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/conda/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/conda/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/conda/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /opt/conda/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/conda/lib/python3.12/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /opt/conda/lib/python3.12/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File /opt/conda/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/conda/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/conda/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# KeyboardInterrupt:
